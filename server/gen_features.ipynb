# %%
from crawler import get_last_matches
from riotAPI import RiotAPI, EUNE_ENDPOINT
import pandas as pd

# %%
matchesPerSummoner = 20

with open('api_key.txt') as f:
    API_KEY = f.read().strip()

riotAPI = RiotAPI(EUNE_ENDPOINT, API_KEY, 'production')


summs = ['52339248', '62835377'] # tmp

# %%
player_matches, last_matches = get_last_matches(summs, {}.keys(), riotAPI, matchesPerSummoner)
# Out:
# https://eune.api.pvp.net/api/lol/eune/v2.2/matchlist/by-summoner/62835377?api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 1:10,107:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/matchlist/by-summoner/52339248?api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 2:10,106:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/matchlist/by-summoner/62835377?api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 3:10,108:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1600328410?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 4:10,109:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1609914356?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 5:10,110:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601634183?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 6:10,111:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1607607428?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 8:10,113:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1600913614?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 9:10,114:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1599599594?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 10:10,115:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1598320288?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 13:10,118:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601220435?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 12:10,117:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1598325440?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 14:10,119:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1600182925?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 15:10,120:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601046343?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 17:10,122:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1607173587?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 18:10,123:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1609994765?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 22:10,127:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1599062605?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 25:10,130:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1607157438?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 24:10,129:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601871630?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 26:10,131:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1598409043?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 27:10,132:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1600126468?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 29:10,134:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1598273652?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 7:10,112:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1597663050?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 11:10,116:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1610611739?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 32:10,137:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1600122777?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 19:10,124:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1600205707?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 20:10,125:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1607249791?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 38:10,143:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1600968015?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 39:10,144:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1599191947?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 21:10,126:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1599348141?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 40:10,145:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1599167403?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 30:10,135:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601638924?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 31:10,136:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601646304?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 42:10,147:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1599506704?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 35:10,140:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1609914356?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 43:10,148:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1598250141?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 37:10,142:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601046343?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 46:10,151:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1598320288?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 45:10,150:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1607173587?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 47:10,152:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1607157438?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 48:10,153:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1607610988?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 16:10,121:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601555919?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 23:10,128:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601046343?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 49:10,154:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1598320288?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 429
# Limits: 50:10,155:600
# Underlying service raised 429 independently of API infrastracture
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1600952490?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 28:10,133:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1610059419?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 34:10,139:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1598320288?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 51:10,156:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1609989203?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 33:10,138:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1601037285?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 36:10,141:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1609901597?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 41:10,146:600
# https://eune.api.pvp.net/api/lol/eune/v2.2/match/1607607428?includeTimeline=false&api_key=RGAPI-4c0c7c95-04de-4b8a-a153-f37f9d31f308 200
# Limits: 44:10,149:600

# %%
summs_idx = [{'summ_id': summ, 'player_num': idx} for idx, summ in enumerate(summs)]
df_summs = pd.DataFrame(summs_idx)
df_summs
# Out:
#    player_num   summ_id
# 0           0  52339248
# 1           1  62835377

# %%
df_matches = pd.DataFrame.from_dict(last_matches, orient='index')
df_matches
# Out:
#             matchDuration                                       participants  \
# 1597663050           1739  [{'team': 'blue', 'cs20': 1.7000000000000002, ...
# 1598250141           1532  [{'team': 'blue', 'cs20': 3.7, 'xpDiff10': 9.4...
# 1598273652           2360  [{'team': 'blue', 'cs20': 7.0, 'xpDiff10': -51...
# 1598320288           2290  [{'team': 'blue', 'cs20': 1.8, 'xpDiff10': 264...
# 1598325440           1226  [{'team': 'blue', 'cs20': 1.5, 'xpDiff10': -75...
# 1598409043           1843  [{'team': 'blue', 'cs20': 0.8, 'xpDiff10': -37...
# 1599062605           1882  [{'team': 'blue', 'cs20': 6.4, 'xpDiff10': -11...
# 1599167403           1796  [{'team': 'blue', 'cs20': 6.6, 'xpDiff10': 132...
# 1599191947           2215  [{'team': 'blue', 'cs20': 0.5, 'xpDiff10': -9....
# 1599348141           1831  [{'team': 'blue', 'cs20': 6.5, 'xpDiff10': -46...
# 1599506704           1638  [{'team': 'blue', 'cs20': 6.6, 'xpDiff10': -66...
# 1599599594           1840  [{'team': 'blue', 'cs20': 4.1, 'xpDiff10': -6....
# 1600122777           1692  [{'team': 'blue', 'cs20': 5.8, 'xpDiff10': -3....
# 1600126468           2108  [{'team': 'blue', 'cs20': 0.5, 'xpDiff10': 67....
# 1600182925           1640  [{'team': 'blue', 'cs20': 3.9000000000000004, ...
# 1600205707           2005  [{'team': 'blue', 'cs20': 7.0, 'xpDiff10': 0, ...
# 1600328410           2335  [{'team': 'blue', 'cs20': 4.3, 'xpDiff10': 5.9...
# 1600913614           2028  [{'team': 'blue', 'cs20': 6.3, 'xpDiff10': -26...
# 1600952490           1946  [{'team': 'blue', 'cs20': 2.1, 'xpDiff10': 148...
# 1600968015           1294  [{'team': 'blue', 'cs20': 7.0, 'xpDiff10': 96....
# 1601037285           1728  [{'team': 'blue', 'cs20': 4.199999999999999, '...
# 1601046343           2121  [{'team': 'blue', 'cs20': 6.3, 'xpDiff10': 75....
# 1601220435           1299  [{'team': 'blue', 'cs20': 5.2, 'xpDiff10': -7....
# 1601555919           2219  [{'team': 'blue', 'cs20': 6.199999999999999, '...
# 1601634183           1251  [{'team': 'blue', 'cs20': 5.199999999999999, '...
# 1601638924           1386  [{'team': 'blue', 'cs20': 8.9, 'xpDiff10': -11...
# 1601646304           1941  [{'team': 'blue', 'cs20': 5.7, 'xpDiff10': -35...
# 1601871630           1638  [{'team': 'blue', 'cs20': 5.0, 'xpDiff10': 86....
# 1607157438           1899  [{'team': 'blue', 'cs20': 5.699999999999999, '...
# 1607173587           2975  [{'team': 'blue', 'cs20': 0.2, 'xpDiff10': -82...
# 1607249791           1839  [{'team': 'blue', 'cs20': 7.6, 'xpDiff10': 90....
# 1607607428           2493  [{'team': 'blue', 'cs20': 4.6, 'xpDiff10': 66....
# 1607610988           2241  [{'team': 'blue', 'cs20': 6.699999999999999, '...
# 1609901597            196  [{'team': 'blue', 'cs20': 6, 'xpDiff10': 0, 't...
# 1609914356           2310  [{'team': 'blue', 'cs20': 7.1, 'xpDiff10': 25....
# 1609989203           2545  [{'team': 'blue', 'cs20': 8.4, 'xpDiff10': 92....
# 1609994765           1769  [{'team': 'blue', 'cs20': 6.6, 'xpDiff10': 89....
# 1610059419           1975  [{'team': 'blue', 'cs20': 6.8, 'xpDiff10': 65....
# 1610611739           2245  [{'team': 'blue', 'cs20': 3.1, 'xpDiff10': 12....
#
#                matchId region                 queueType
# 1597663050  1597663050   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1598250141  1598250141   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1598273652  1598273652   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1598320288  1598320288   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1598325440  1598325440   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1598409043  1598409043   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1599062605  1599062605   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1599167403  1599167403   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1599191947  1599191947   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1599348141  1599348141   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1599506704  1599506704   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1599599594  1599599594   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1600122777  1600122777   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1600126468  1600126468   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1600182925  1600182925   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1600205707  1600205707   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1600328410  1600328410   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1600913614  1600913614   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1600952490  1600952490   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1600968015  1600968015   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1601037285  1601037285   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1601046343  1601046343   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1601220435  1601220435   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1601555919  1601555919   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1601634183  1601634183   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1601638924  1601638924   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1601646304  1601646304   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1601871630  1601871630   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1607157438  1607157438   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1607173587  1607173587   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1607249791  1607249791   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1607607428  1607607428   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1607610988  1607610988   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1609901597  1609901597   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1609914356  1609914356   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1609989203  1609989203   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1609994765  1609994765   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1610059419  1610059419   EUNE  TEAM_BUILDER_RANKED_SOLO
# 1610611739  1610611739   EUNE  TEAM_BUILDER_RANKED_SOLO

# %%
# df_player_matches = pd.DataFrame(player_matches)
# df_player_matches.ix[0]['52339248']

player_matches_unnested = [{"summ_id": key, "match_id": item} for key, items in player_matches.items() for item in items]
df_player_matches = pd.DataFrame(player_matches_unnested)

# %%
def gen_player_features(matches):
    summId = matches.ix[0]['summ_id']
    player_num = matches.ix[0]['player_num']

    def getInfo(match):
        return pd.Series([info for info in match['participants'] if info['summonerId'] == summId][0])
    
    infos = matches.apply(getInfo, axis = 1)

    
    totalGames = max(len(matches.index), 1)

    # winrate
    winrate = infos['winner'].sum() / totalGames
    
    # GPM
    GPM = 60.0 * infos['goldEarned'].sum() / matches['matchDuration'].sum()
    
    # KDA
    kills = infos['kills'].sum()
    assists = infos['assists'].sum()
    deaths = infos['deaths'].sum()

    KDA = (kills+deaths) / max(deaths, 1)
    KD = kills / max(deaths, 1)
    
    largestKillingSpree = infos['largestKillingSpree'].mean()
    
    totalDamageDealt = infos['totalDamageDealt'].mean()
    
    totalDamageDealtToChampions = infos['totalDamageDealtToChampions'].mean()
    
    totalDamageTaken = infos['totalDamageTaken'].mean()
    
    totalTimeCrowdControlDealt = infos['totalTimeCrowdControlDealt'].mean()
    
    # timeline stuff
    
    cs10 = infos['cs10'].mean()
    cs20 = infos['cs20'].mean()
    
    csDiff10 = infos['csDiff10'].mean()
    csDiff20 = infos['csDiff20'].mean()
    
    gpm10 = infos['gpm10'].mean()
    gpm20 = infos['gpm20'].mean()
    
    xpDiff10 = infos['xpDiff10'].mean()
    xpDiff20 = infos['xpDiff20'].mean()
    
    return pd.Series({
#             'summ_id': summId,
            'player_num': player_num,
            'winrate': winrate,
            'GPM': GPM,
            'KDA': KDA,
            'KD': KD,
            'largestKillingSpree': largestKillingSpree,
            'totalDamageDealt': totalDamageDealt,
            'totalDamageDealtToChampions': totalDamageDealtToChampions,
            'totalDamageTaken': totalDamageTaken,
            'totalTimeCrowdControlDealt': totalTimeCrowdControlDealt,
            'cs10': cs10,
            'cs20': cs20,
            'csDiff10': csDiff10,
            'csDiff20': csDiff20,
            'gpm10': gpm10,
            'gpm20': gpm20,
            'xpDiff10': xpDiff10,
            'xpDiff20': xpDiff20
        })

    
df_features = pd.merge(df_summs, df_player_matches, left_on = 'summ_id', right_on = 'summ_id').set_index('match_id').join(df_matches).groupby(['summ_id']).apply(gen_player_features)
df_features = df_features.ix[:, ["player_num", "winrate", "GPM", "KDA", "KD", "largestKillingSpree", "totalDamageDealt",
        "totalDamageDealtToChampions", "totalDamageTaken","totalTimeCrowdControlDealt",
        "cs10", "cs20", "csDiff10", "csDiff20", "gpm10", "gpm20", "xpDiff10", "xpDiff20"]].set_index(['player_num'])

df_features
# Out:
#             winrate         GPM       KDA        KD  largestKillingSpree  \
# player_num
# 0.0            0.65  319.110556  1.445946  0.445946                 0.95
# 1.0            0.30  331.007980  1.488889  0.488889                 1.05
#
#             totalDamageDealt  totalDamageDealtToChampions  totalDamageTaken  \
# player_num
# 0.0                 24115.95                       7662.1           19154.2
# 1.0                 78112.10                      12931.0           25092.8
#
#             totalTimeCrowdControlDealt   cs10   cs20  csDiff10  csDiff20  \
# player_num
# 0.0                             141.05  0.715  1.075     0.090    0.3650
# 1.0                             558.50  2.795  3.310     0.045   -0.1175
#
#               gpm10    gpm20  xpDiff10  xpDiff20
# player_num
# 0.0         185.945  333.195    12.715   30.5525
# 1.0         209.940  336.200    -5.670  -23.5725

# %%
features = df_features.values.tolist()

features
# Out:
# [[0.65,
#   319.11055646945374,
#   1.445945945945946,
#   0.44594594594594594,
#   0.95,
#   24115.95,
#   7662.1,
#   19154.2,
#   141.05,
#   0.7150000000000001,
#   1.0750000000000002,
#   0.09000000000000005,
#   0.36500000000000005,
#   185.94500000000002,
#   333.195,
#   12.714999999999993,
#   30.5525],
#  [0.3,
#   331.0079804808621,
#   1.488888888888889,
#   0.4888888888888889,
#   1.05,
#   78112.1,
#   12931.0,
#   25092.8,
#   558.5,
#   2.795000000000001,
#   3.31,
#   0.045,
#   -0.11749999999999998,
#   209.94,
#   336.2,
#   -5.669999999999999,
#   -23.5725]]

# %%
[feature for sublist in features for feature in sublist]
# Out:
# 34
